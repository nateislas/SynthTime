# %%
from google.colab import drive
drive.mount('/content/drive')

root = '/content/drive/MyDrive/Colab Notebooks/volatility trading/sequence_generation'
os.chdir(root)

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# Mounted at /content/drive
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-6bddd8c3b292> in <cell line: 0>()
#       3
#       4 root = '/content/drive/MyDrive/Colab Notebooks/volatility trading/'
# ----> 5 os.chdir(root)
#       6
#       7 device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
#
# NameError: name 'os' is not defined
